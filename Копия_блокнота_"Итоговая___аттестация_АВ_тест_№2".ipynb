# %% [markdown]
# <a href="https://colab.research.google.com/github/SwetlLOG/-Colab/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%98%D1%82%D0%BE%D0%B3%D0%BE%D0%B2%D0%B0%D1%8F___%D0%B0%D1%82%D1%82%D0%B5%D1%81%D1%82%D0%B0%D1%86%D0%B8%D1%8F_%D0%90%D0%92_%D1%82%D0%B5%D1%81%D1%82_%E2%84%962%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание
# Подведите результаты эксперимента в экселе по следующим данным: ab_stats.csv - Google Диск:
# Стат значимо ли отличается ARPPU в двух группах ? Какие рекомендации дадите
# менеджеру?

# %%
from scipy.stats import ttest_1samp
import numpy as np
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/ab_stats.csv')
data
# Out:
#        revenue  num_purchases  purchase ab_group  av_site visit
# 0          0.0              0         0        A       9.040174
# 1          0.0              0         0        A       4.811628
# 2          0.0              0         0        A       7.342623
# 3          0.0              0         0        A       7.744581
# 4          0.0              0         0        A      10.511814
# ...        ...            ...       ...      ...            ...
# 23647      0.0              0         0        B      10.207152
# 23648      0.0              0         0        B       5.148761
# 23649      0.0              0         0        B       4.809019
# 23650      0.0              0         0        B       8.127488
# 23651      0.0              0         0        B       8.928102
#
# [23652 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23652 entries, 0 to 23651
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   revenue        23652 non-null  float64
#  1   num_purchases  23652 non-null  int64
#  2   purchase       23652 non-null  int64
#  3   ab_group       23652 non-null  object
#  4   av_site visit  23652 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 924.0+ KB

# %%
data.shape
# Out:
# (23652, 5)

# %%
data.describe()
# Out:
#             revenue  num_purchases      purchase  av_site visit
# count  23652.000000   23652.000000  23652.000000   23652.000000
# mean       0.324689       0.043590      0.020717       7.013112
# std        9.557730       1.079403      0.142438       3.154584
# min        0.000000       0.000000      0.000000     -12.073486
# 25%        0.000000       0.000000      0.000000       5.173787
# 50%        0.000000       0.000000      0.000000       7.007936
# 75%        0.000000       0.000000      0.000000       8.864119
# max     1303.609284     152.000000      1.000000      22.446822

# %% [markdown]
# На данном этапе можем сделать вывод, что перед нами корректные данные, можем их использовать доя дальнейшего анализа

# %%
data[data['ab_group']=='A'].describe()
# Out:
#             revenue  num_purchases      purchase  av_site visit
# count  11835.000000   11835.000000  11835.000000   11835.000000
# mean       0.404462       0.050697      0.021631       6.974724
# std       13.133218       1.467511      0.145481       2.023533
# min        0.000000       0.000000      0.000000     -12.073486
# 25%        0.000000       0.000000      0.000000       5.656155
# 50%        0.000000       0.000000      0.000000       6.982329
# 75%        0.000000       0.000000      0.000000       8.345572
# max     1303.609284     152.000000      1.000000      17.728836

# %%
data[data['ab_group']=='B'].describe()
# Out:
#             revenue  num_purchases      purchase  av_site visit
# count  11817.000000   11817.000000  11817.000000   11817.000000
# mean       0.244794       0.036473      0.019802       7.051559
# std        3.176534       0.418480      0.139325       3.976799
# min        0.000000       0.000000      0.000000      -8.286822
# 25%        0.000000       0.000000      0.000000       4.380984
# 50%        0.000000       0.000000      0.000000       7.060873
# 75%        0.000000       0.000000      0.000000       9.768648
# max      113.830000      25.000000      1.000000      22.446822

# %%
data.groupby('ab_group')['revenue'].describe()
# Out:
#             count      mean        std  min  25%  50%  75%          max
# ab_group
# A         11835.0  0.404462  13.133218  0.0  0.0  0.0  0.0  1303.609284
# B         11817.0  0.244794   3.176534  0.0  0.0  0.0  0.0   113.830000

# %%
k1 = data[data['ab_group']=='A']['revenue'].sum()
k1
# Out:
# 4786.807972

# %%
k2 = data[data['ab_group']=='B']['revenue'].sum()
k2
# Out:
# 2892.7357889999985

# %%
n1 = data[data['ab_group']=='A'].shape[0]
n2 = data[data['ab_group']=='B'].shape[0]

# %%
from statsmodels.stats import proportion

z_score, z_pvalue = proportion.proportions_ztest(np.array([k1, k2]),
                                                   np.array([n1, n2]))
print('Results are ','z_score =%.3f, pvalue = %.3f'%(z_score, z_pvalue))
# Out:
# Results are  z_score =26.220, pvalue = 0.000

# %% [markdown]
# ###После анализа экперимента можно сделать след выводы:
#  ##### ARPPU  в группах А и В значительно отличаются, и в соответствии с исследованиями можно дать рекомендации менеджеру по использованию модели работы по принципу группы А.
# .
